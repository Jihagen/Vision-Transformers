# %%
import pandas as pd

df = pd.read_pickle("data/selected_uniform_25.pkl")
len(df)
# Out:
# 25

# %%
df
# Out:
#     filename   interestingness_label
# 0   0211.jpg         Not Interesting
# 1   0881.jpg         Not Interesting
# 2   0462.jpg         Not Interesting
# 3   0462.jpg         Not Interesting
# 4   0462.jpg         Not Interesting
# 5   0754.jpg    Slightly Interesting
# 6   0044.jpg    Slightly Interesting
# 7   0047.jpg    Slightly Interesting
# 8   0129.jpg    Slightly Interesting
# 9   0602.jpg    Slightly Interesting
# 10  0149.jpg  Moderately Interesting
# 11  0733.jpg  Moderately Interesting
# 12  0793.jpg  Moderately Interesting
# 13  0858.jpg  Moderately Interesting
# 14  0523.jpg  Moderately Interesting
# 15  0852.jpg        Very Interesting
# 16  0928.jpg        Very Interesting
# 17  0564.jpg        Very Interesting
# 18  0842.jpg        Very Interesting
# 19  0818.jpg        Very Interesting
# 20  0821.jpg   Extremely Interesting
# 21  0839.jpg   Extremely Interesting
# 22  0839.jpg   Extremely Interesting
# 23  0821.jpg   Extremely Interesting
# ...

# %%
df_ci = pd.read_pickle("data/df_common_machine_int.pkl")
len(df_ci)
# Out:
# 1000

# %%
df_ci
# Out:
#         interestingness_value  \
# img_id
# 1                        1.32
# 2                        1.53
# 3                        1.24
# 4                        1.49
# 5                        1.31
# ...                       ...
# 996                      1.89
# 997                      2.32
# 998                      2.12
# 999                      2.05
# 1000                     1.83
#
#                                                  img_path  ci_score  \
# img_id
# 1        /nasdata/OpenImagesV7/train/41180264cfe0bffa.jpg  0.011470
# 2        /nasdata/OpenImagesV7/train/5c685e499e6f284c.jpg  0.011470
# 3        /nasdata/OpenImagesV7/train/d7f8321325bb0a79.jpg  0.011470
# 4        /nasdata/OpenImagesV7/train/80e5daa293c6a5bb.jpg  0.011470
# 5        /nasdata/OpenImagesV7/train/8d653fbb5149aebc.jpg  0.011470
# ...                                                   ...       ...
# 996     /nasdata/flickrUserData/64038177@N08/fav/50134...  0.666319
# ...

# %%
df_pers = pd.read_pickle("data/df_generated-personas-sample.pkl")
len(df_pers)
# Out:
# 100

# %%
df_pers
# Out:
#               age   gender         country      continent  \
# id
# 2255  65 or older     male         Nigeria         Africa
# 1055        40-44     male          Uganda         Africa
# 3406        60-64     male       Venezuela  South America
# 5244  65 or older   female      Luxembourg         Europe
# 4254        30-34   female         Namibia         Africa
# ...           ...      ...             ...            ...
# 7844        35-39   female       Argentina  South America
# 8877        55-59  diverse           Kenya         Africa
# 9332        35-39     male  United Kingdom         Europe
# 8700        20-24     male       Palestine           Asia
# 4205  65 or older  diverse           Spain         Europe
#
#                        job_branch mental_workload       emotion
# id
# 2255     Recreational Participant            high          fear
# 1055       Arts and Entertainment             low       disgust
# 3406      Media and Communication             low           sad
# ...

# %%
import pickle

with open("gdv_500_0\gdv.pkl", "rb") as f:
    data = pickle.load(f)

type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['sorted_layers', 'layer_data', 'gdv_per_layer', 'gdv_per_layer_cosine', 'meta'])

# %%
data["meta"]
# Out:
# {'labels': ['Slightly Interesting',
#   'Moderately Interesting',
#   'Slightly Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Slightly Interesting',
#   'Slightly Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Slightly Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Slightly Interesting',
#   'Moderately Interesting',
#   'Moderately Interesting',
#   'Slightly Interesting',
#   'Slightly Interesting',
#   'Slightly Interesting',
# ...
