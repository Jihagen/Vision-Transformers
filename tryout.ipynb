# %%
import pickle
d = pickle.load(open("res/gdv_100_0/gdv.pkl","rb"))
layer = d["sorted_layers"][0]
coords_umap = next(iter(d["layer_data"][layer]["projections"]["umap"].values()))["coords"]
coords_tsne = next(iter(d["layer_data"][layer]["projections"]["tsne"].values()))["coords"]
coords_pca12 = d["layer_data"][layer]["projections"]["pca"]["PC12"]["coords"]
